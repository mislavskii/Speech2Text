# %% [markdown]
# # Translating Subtitles

# %%
import sys, os
import pandas as pd

project_root = os.path.abspath("..")  # Assuming the notebook is in a subfolder
sys.path.append(project_root)

from config import *

# %%
sub_tsv = r'..\files\arjan\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.en.tsv'
sub_tsv
# Out:
# '..\\files\\arjan\\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.en.tsv'

# %%
df = pd.read_csv(sub_tsv, sep='\t')
df
# Out:
#        Start Time      End Time  \
# 0    00:00:00.000  00:00:06.380
# 1    00:00:07.200  00:00:09.800
# 2    00:00:09.800  00:00:15.640
# 3    00:00:16.000  00:00:20.480
# 4    00:00:20.480  00:00:25.959
# ..            ...           ...
# 231  00:15:47.219  00:15:49.138
# 232  00:15:49.138  00:15:52.378
# 233  00:15:52.378  00:15:55.459
# 234  00:15:55.459  00:15:58.698
# 235  00:15:58.698  00:16:01.098
#
#                                                   Text
# 0    Today I'm going to walk you through how to set...
# 1             I'll start with code that has zero tests
# 2    I'll add PyTest, show you step-by-step how to ...
# 3    Including one feature almost no one knows abou...
# 4    I'll share some practical tips to make your te...
# ..                                                 ...
# 231      If you want to learn more about what to test,
# 232        how to set up a complete set of unit tests,
# 233  check out this video where I do a refactoring ...
# 234         and use unit tests to create a safety net.
# 235        Thanks for watching, and see you next time.
#
# [236 rows x 3 columns]

# %% [markdown]
# ## Obtaining translations from Yandex

# %%
import requests as rq
import json

# %%
mid = len(df) // 2
mid
# Out:
# 118

# %%
texts = df[:mid].Text.to_list()
texts
# Out:
# ["Today I'm going to walk you through how to set up PyTest from scratch in a really simple minimalistic way, Marie Kondo style",
#  "I'll start with code that has zero tests",
#  "I'll add PyTest, show you step-by-step how to write unit tests and even cover some advanced features along the way",
#  "Including one feature almost no one knows about that's actually really cool. At the end",
#  "I'll share some practical tips to make your tests cleaner faster and more maintainable. Let's get started",
#  "Obviously, the first thing that you're going to need to do is install PyTest. You can install it using any package manager",
#  "But in this video, I'm going to use uv which is fast and efficient. To add PyTest to your Py project file",
#  'simply type uv add',
#  'dash test dev PyTest',
#  'This dev flag here ensures that PyTest is only installed in development mode, not in production',
#  'You can also see that when you take a look at the Py project file',
#  "So here we have dependencies, the regular dependencies of this particular example project, what these are doesn't really matter",
#  'But you also see we have a dev dependency group that contains now the PyTest package and PyTest mock',
#  'If you just checked out some code from a git repository that has a Py project file',
#  'You need to install dependencies. You can install the dev local dependencies only by simply typing uv sync',
#  'extra dev',
#  'And this is going to install all the dev dependencies local on the machine',
#  "If you're using pip and you want to install PyTest, then that's going to be pip install PyTest",
#  "dash test dev and if you're using a tool like poetry, then it's going to be poetry add",
#  'dash test dev PyTest, more or less the same as uv. The key takeaway here though is to always install PyTest as a dev',
#  'dependency and use a virtual environment. Before I start adding tests',
#  "Let's first take a look at the actual project we're dealing with here",
#  'So as you can see, there is a source folder right here that contains a bunch of files',
#  "Now what these files are exactly doesn't matter",
#  "This is actually taken from Bracere, which is an open source project that we're working on that allows you to create",
#  'translations and transcripts',
#  "Using AI. We're using it ourselves for our YouTube videos",
#  'But the question is of course if you have a source folder like this, where do you put the test, right?',
#  "Now there's some people that say well you should put it inside your source folder. That's typically not what I do",
#  'I like to put my test in a separate folder called test',
#  "So let's add a new folder here and let's call that test like so now if you're using VS code like I am you also need",
#  'To configure it to actually recognize PyTest and you can do that by creating settings for your workspace',
#  'So here I have some sample settings that you can use for testing',
#  "So one of these is that we have to enable PyTest that way VS code is going to recognize that you're going to be using",
#  'PyTest',
#  'Another thing that you need to do is supply this folder so that VS code can actually find the test that you want to run',
#  "Now there's also some other options here that I have disabled for now",
#  'One is that you can actually disable unit tests',
#  "So then we'll only use PyTest and another thing you can do is you can supply this setting which is an environment file",
#  "And then actually when you're running your test, it's going to rely on the contents of this particular environment file",
#  "I'm not using it in this project",
#  "but that's actually a really useful setting to have and in VS code itself on the left or on the right or wherever else you",
#  'have configured your',
#  "Icons to be in the interface. You're going to have this little icon here called testing",
#  'And if you click that you see that there are now zero tests actually in the past',
#  'I did already run a bunch of tests here that while I was preparing a script for this video',
#  'But at the moment there are no tests as an empty test folder, right?',
#  'But this interface is there because we define these things like for example, if I change these into comments',
#  "Then you're going to see that there is no test in a workspace not been configured yet",
#  'when I enable PyTest',
#  "Then it's going to see this and then it's simply going to recognize that we have a folder with some source code",
#  "And if I also tell it where the working directory is then it's going to show us this test",
#  'Working directory which pass because there are zero tests at the moment. So pretty straightforward',
#  "But it's just something that you're gonna have to do",
#  'Another thing you might want to do is in your pipe project files',
#  "Make sure that your Python path is set so that PyTest can find your modules when you're running your test",
#  "And by the way, if your project already uses unit test Python's standard library module for testing",
#  "Don't worry PyTest can actually still run these without any issue. So you can basically migrate",
#  'Gradually instead of rewriting everything all at once',
#  'now testing of course',
#  "It's just one piece of the puzzle a solid architecture can save you from costly mistakes down the road whether it's unmaintainable code",
#  'Performance issues unexpected bugs creeping in to help you with that',
#  "I've put together a free software architecture checklist covers the key principles to keep your projects scalable",
#  'maintainable and free of expensive rewrites grab your copy at arjan.codes/checklist ',
#  'The link is also in the description of this video',
#  "Now let's move on to actually writing some tests when you write tests",
#  'The first thing that you need to think about is naming',
#  'Convention and you do have a sort of folder structure here already and typically what I like to do is follow this',
#  'Structure to a T so my test folder is going to have the same structure as my source folder',
#  "That way it's easy to find a test belonging to a particular file",
#  'And other things I do is that I name the files test underscore module name',
#  'So for example, if you take a look at this file timer.py',
#  "That's at the root of the source folder. What I would then do is that under my test folder. I would create a file test",
#  'Timer.py or if I have a file called timestamp utils, I would do test timestamp',
#  'utils',
#  'So your test file always contains the module name',
#  'Another thing you need to do is make sure if you define a test function',
#  'It must start with test underscore. Otherwise pytest is not going to recognize it',
#  'Now if we take a look at this particular module here timestamp utils',
#  "You see that there's a function here called to timestamp that takes a time Delta and returns a string",
#  'There are some special cases here like if the duration is',
#  "Negative then it's going to simply return zero and then it's simply going to compute a string version of that particular time Delta",
#  "So not a very complicated function, but it's something that we might want to test",
#  'Right, and of course like a YouTube chef, I have already prepared some of these test cases for you',
#  "So I don't have to bore you with me writing all that code. So in my test timestamp utils",
#  "I'm importing the to timestamp function from the source folder",
#  'I also need time Delta from daytime and then I have a bunch of functions',
#  'Like I said, each of these start with test underscore that way pytest is going to recognize them',
#  'So here I have an example to check that to timestamp actually returns a string this by the way would also be a really good',
#  "Candidate for some parametric type of testing which is a more advanced way of writing tests that I won't cover today",
#  'I did do a video on the channel while back about hypothesis property-based testing those kind of things actually pretty',
#  'Interesting way of dealing with unit test and I have a bunch of other specific tests here',
#  "Like I'm going to test the negative duration. So if a negative number of seconds, does it actually return this?",
#  'I also test large duration. So if we have multiple days, does that also work?',
#  'how about',
#  'Specific time like one hour two minutes three seconds. What happens to a time Delta of zero? Does that work correctly?',
#  'one millisecond and also some other cases like checking what happens with',
#  '999 milliseconds or with 500 microseconds, which should be rounded to zero now in order to run these tests',
#  "I can simply switch to my console and then I type pytest and as you can see it's going to collect all of these tests",
#  'By looking in the test folder and it found a test. We got one warning',
#  "This is a deprecation warning because of a specific thing that the package is using that that I'm trying to test here",
#  'But all of these tests pass you can also run these tests right from the VS code interface',
#  'You do that by clicking this icon',
#  "If you don't see that icon by the way",
#  'Just click right here and then you can select',
#  "Testing here and then you're going to see it pop up and now you see we have to test folder here",
#  "I can press play and it's going to run these tests right from a VS code",
#  'The nice thing about the interface in VS code that you can then also explore the test',
#  'So for example here, you can click through these tests and then see what kind of output the test did produce',
#  "And that's what you're going to see. Let's take a look at another example. That's slightly more complicated",
#  'So in the source folder, I also have a translation folder here',
#  'and there is a translation API file and I',
#  'Let me just move this out of the way.',
#  'If you scroll down, you see that we have a bunch of functions here,',
#  'like splitting by breakpoint,',
#  'translating it by calling the OpenAI translator,',
#  'an asynchronous version of that, and a couple of other things as well.',
#  'Now, if you want to add a test for this particular file,']

# %%
source_language = 'en'
target_language = 'ru'

body = {
    "sourceLanguageCode": source_language,
    "targetLanguageCode": target_language,
    "texts": texts,
    "folderId": y_folder_ID
}

headers = {
    "Content-Type": "application/json",
    "Authorization": "Api-Key {:s}".format(y_key)
}

response = rq.post(
    'https://translate.api.cloud.yandex.net/translate/v2/translate',
    json = body,
    headers = headers
)

print(response.status_code)
# Out:
# 200

# %%
translations = response.json()['translations']
translations
# Out:
# [{'text': 'Сегодня я расскажу вам о том, как настроить PyTest с нуля очень простым минималистичным способом в стиле Мари Кондо'},
#  {'text': 'Я начну с кода, в котором нет тестов'},
#  {'text': 'Я добавлю PyTest, покажу вам шаг за шагом, как писать модульные тесты, и даже расскажу о некоторых расширенных функциях на этом пути'},
#  {'text': 'Включая одну функцию, о которой почти никто не знает, и которая на самом деле очень крутая. В конце'},
#  {'text': 'Я поделюсь несколькими практическими советами, которые помогут сделать ваши тесты более понятными, быстрыми и удобными в обслуживании. Давайте начнем'},
#  {'text': 'Очевидно, что первое, что вам нужно будет сделать, это установить PyTest. Вы можете установить его с помощью любого менеджера пакетов'},
#  {'text': 'Но в этом видео я собираюсь использовать uv, который работает быстро и эффективно. Как добавить PyTest в ваш файл проекта Py'},
#  {'text': 'просто введите uv add'},
#  {'text': 'dash-тест dev PyTest'},
#  {'text': 'Этот флаг разработчика здесь гарантирует, что PyTest устанавливается только в режиме разработки, а не в рабочей среде'},
#  {'text': 'Вы также можете увидеть это, если взглянете на файл проекта Py'},
#  {'text': 'Итак, здесь у нас есть зависимости, обычные зависимости этого конкретного примера проекта, что это на самом деле не имеет значения'},
#  {'text': 'Но вы также видите, что у нас есть группа зависимостей dev, которая теперь содержит пакет PyTest и макет PyTest'},
#  {'text': 'Если вы только что извлекли какой-то код из репозитория git, в котором есть файл проекта Py'},
#  {'text': 'Вам необходимо установить зависимости. Вы можете установить только локальные зависимости разработчика, просто набрав команду uv sync'},
#  {'text': 'дополнительный разработчик'},
#  {'text': 'И это приведет к установке всех зависимостей разработчика локально на компьютере'},
#  {'text': 'Если вы используете pip и хотите установить PyTest, то это будет pip install PyTest'},
#  {'text': 'dash test dev, и если вы используете такой инструмент, как poetry, то это будет poetry add'},
#  {'text': 'dash-тест dev PyTest, более или менее такой же, как и uv. Однако ключевой вывод здесь - всегда устанавливать PyTest как разработчик'},
#  {'text': 'зависимости и использовать виртуальную среду. Прежде чем я начну добавлять тесты'},
#  {'text': 'Давайте сначала взглянем на реальный проект, с которым мы здесь имеем дело'},
#  {'text': 'Итак, как вы можете видеть, прямо здесь есть исходная папка, содержащая множество файлов'},
#  {'text': 'Теперь не имеет значения, что именно представляют собой эти файлы'},
#  {'text': 'На самом деле это взято из Bracere, проекта с открытым исходным кодом, над которым мы работаем и который позволяет вам создавать'},
#  {'text': 'переводы и стенограммы'},
#  {'text': 'Используя искусственный интеллект. Мы сами используем его для наших видеороликов на YouTube'},
#  {'text': 'Но, конечно, вопрос в том, что если у вас есть исходная папка, подобная этой, куда вы помещаете тест, верно?'},
#  {'text': 'Некоторые люди говорят, что вам следует поместить его в свою исходную папку. Обычно я так не поступаю'},
#  {'text': 'Мне нравится помещать свой тест в отдельную папку под названием test'},
#  {'text': 'Итак, давайте добавим сюда новую папку и назовем этот тест так. Итак, если вы используете VS code, как я, вам также понадобится'},
#  {'text': 'Чтобы настроить его так, чтобы он действительно распознавал PyTest, и вы можете сделать это, создав настройки для своего рабочего пространства'},
#  {'text': 'Итак, здесь у меня есть несколько примеров настроек, которые вы можете использовать для тестирования'},
#  {'text': 'Итак, один из них заключается в том, что мы должны включить PyTest, чтобы VS code мог распознавать, что вы собираетесь использовать'},
#  {'text': 'Пытливый'},
#  {'text': 'Еще одна вещь, которую вам нужно сделать, это указать эту папку, чтобы VS code действительно мог найти тест, который вы хотите запустить'},
#  {'text': 'Теперь здесь есть и некоторые другие опции, которые я пока отключил'},
#  {'text': 'Во-первых, вы действительно можете отключить модульные тесты'},
#  {'text': 'Итак, тогда мы будем использовать только PyTest, и еще одна вещь, которую вы можете сделать, - это указать этот параметр, который является файлом среды'},
#  {'text': 'И затем, на самом деле, когда вы запускаете свой тест, он будет опираться на содержимое этого конкретного файла среды'},
#  {'text': 'Я не буду использовать его в этом проекте'},
#  {'text': 'но на самом деле это действительно полезная настройка, которую можно использовать и в самом VS code слева, и справа, и где бы вы еще ни находились.'},
#  {'text': 'настроили свой'},
#  {'text': 'Значки, которые должны быть в интерфейсе. Здесь у вас будет маленький значок под названием "тестирование"'},
#  {'text': 'И если вы нажмете на нее, то увидите, что на самом деле в прошлом не было никаких тестов'},
#  {'text': 'Я уже провел здесь несколько тестов, пока готовил сценарий для этого видео'},
#  {'text': 'Но на данный момент нет тестов в виде пустой тестовой папки, верно?'},
#  {'text': 'Но этот интерфейс существует, потому что мы определяем эти вещи, например, если я изменю их в комментариях'},
#  {'text': 'Затем вы увидите, что в рабочей области, которая еще не настроена, нет ни одного теста'},
#  {'text': 'когда я включаю PyTest'},
#  {'text': 'Затем он увидит это, а затем просто распознает, что у нас есть папка с некоторым исходным кодом'},
#  {'text': 'И если я также сообщу ему, где находится рабочий каталог, то он покажет нам этот тест'},
#  {'text': 'Рабочий каталог, который проходит, потому что на данный момент нет тестов. Так что все довольно просто'},
#  {'text': 'Но это просто то, что тебе придется сделать.'},
#  {'text': 'Еще одна вещь, которую вы, возможно, захотите сделать, - это внести изменения в файлы вашего проекта pipe'},
#  {'text': 'Убедитесь, что ваш путь к Python задан таким образом, чтобы PyTest мог находить ваши модули при запуске теста'},
#  {'text': 'И, кстати, если ваш проект уже использует модуль стандартной библиотеки unit test Python для тестирования'},
#  {'text': 'Не волнуйтесь, PyTest по-прежнему может запускать их без каких-либо проблем. Таким образом, вы можете в принципе перенести'},
#  {'text': 'Постепенно, вместо того чтобы переписывать все сразу'},
#  {'text': 'теперь, конечно, тестирование'},
#  {'text': 'Это всего лишь одна часть головоломки надежная архитектура может уберечь вас от дорогостоящих ошибок в будущем, будь то код, который невозможно поддерживать'},
#  {'text': 'Проблемы с производительностью, появление неожиданных ошибок, которые помогут вам в этом'},
#  {'text': 'Я составил контрольный список архитектуры свободного программного обеспечения, в котором описаны ключевые принципы обеспечения масштабируемости ваших проектов'},
#  {'text': 'удобный в обслуживании и не требующий дорогостоящей правки, получите свой экземпляр на arjan.codes /контрольный список '},
#  {'text': 'Ссылка также есть в описании этого видео'},
#  {'text': 'Теперь давайте перейдем к фактическому написанию некоторых тестов, когда вы пишете тесты'},
#  {'text': 'Первое, о чем вам нужно подумать, - это название'},
#  {'text': 'Соглашение, и у вас здесь уже есть своего рода структура папок, и, как правило, мне нравится следовать этому'},
#  {'text': 'Таким образом, моя тестовая папка будет иметь ту же структуру, что и моя исходная папка'},
#  {'text': 'Таким образом, будет легко найти тест, относящийся к определенному файлу'},
#  {'text': 'И еще одна вещь, которую я делаю, - это то, что я присваиваю файлам название модуля с подчеркиванием test'},
#  {'text': 'Так, например, если вы взглянете на этот файл timer.py'},
#  {'text': 'Он находится в корне исходной папки. Затем я бы сделал это в своей тестовой папке. Я бы создал файл test'},
#  {'text': 'Timer.py или, если у меня есть файл с именем timestamp utils, я бы сделал тестовую временную метку'},
#  {'text': 'утилиты'},
#  {'text': 'Таким образом, ваш тестовый файл всегда содержит имя модуля'},
#  {'text': 'Еще одна вещь, которую вам нужно сделать, это убедиться, что вы определили тестовую функцию'},
#  {'text': 'Оно должно начинаться с тестового подчеркивания. В противном случае pytest не распознает его'},
#  {'text': 'Теперь, если мы взглянем на этот конкретный модуль здесь, timestamp utils'},
#  {'text': 'Вы видите, что здесь есть функция, вызываемая для timestamp, которая принимает временную разницу и возвращает строку'},
#  {'text': 'Здесь есть некоторые особые случаи, например, если продолжительность'},
#  {'text': 'Отрицательный, тогда он просто вернет ноль, а затем просто вычислит строковую версию этой конкретной временной дельты'},
#  {'text': 'Таким образом, это не очень сложная функция, но это то, что мы, возможно, захотим протестировать'},
#  {'text': 'Да, и, конечно же, как шеф-повар YouTube, я уже подготовил для вас несколько таких тестовых примеров'},
#  {'text': 'Чтобы не утомлять вас рассказом о том, как я пишу весь этот код. Итак, в моем тесте timestamp использует'},
#  {'text': 'Я импортирую функцию to timestamp из исходной папки'},
#  {'text': 'Мне также нужна разница во времени с дневным, и тогда у меня будет куча функций'},
#  {'text': 'Как я уже сказал, каждый из них начинается с тестового подчеркивания, чтобы pytest мог их распознать'},
#  {'text': 'Итак, здесь у меня есть пример, позволяющий проверить, что to timestamp действительно возвращает строку, это, кстати, тоже было бы действительно хорошим решением.'},
#  {'text': 'Кандидат для некоторого параметрического типа тестирования, который является более продвинутым способом написания тестов, о котором я сегодня не буду рассказывать'},
#  {'text': 'Некоторое время назад я опубликовал на своем канале видео о тестировании на основе свойств гипотез, и такие вещи на самом деле очень хороши.'},
#  {'text': 'Интересный способ работы с модульным тестированием, и здесь у меня есть куча других специфических тестов'},
#  {'text': 'Например, я собираюсь проверить отрицательную длительность. Итак, если задано отрицательное количество секунд, действительно ли это возвращает значение?'},
#  {'text': 'Я также тестирую большую продолжительность. Итак, если у нас будет несколько дней, это тоже сработает?'},
#  {'text': 'как насчет'},
#  {'text': 'Определенное время, например, один час, две минуты и три секунды. Что происходит с разницей во времени, равной нулю? Правильно ли это работает?'},
#  {'text': 'одну миллисекунду, а также в некоторых других случаях, таких как проверка того, что происходит с'},
#  {'text': '999 миллисекунд или 500 микросекунд, которые теперь следует округлить до нуля, чтобы выполнить эти тесты'},
#  {'text': 'Я могу просто переключиться на свою консоль, а затем ввести pytest, и, как вы можете видеть, он соберет все эти тесты'},
#  {'text': 'Заглянув в папку с тестами, мы нашли тест. Мы получили одно предупреждение'},
#  {'text': 'Это предупреждение об устаревании из-за специфической функции, используемой пакетом, которую я пытаюсь протестировать здесь'},
#  {'text': 'Но все эти тесты проходят успешно, вы также можете запустить эти тесты прямо из интерфейса VS code'},
#  {'text': 'Вы можете сделать это, нажав на этот значок'},
#  {'text': 'Если вы, кстати, не видите этот значок,'},
#  {'text': 'Просто нажмите прямо здесь, и затем вы сможете выбрать'},
#  {'text': 'Тестируем здесь, а затем вы увидите всплывающее окно, и теперь вы видите, что нам нужно протестировать папку здесь'},
#  {'text': 'Я могу нажать play, и он запустит эти тесты прямо из кода VS'},
#  {'text': 'Самое приятное в интерфейсе VS code то, что вы также можете изучить его в ходе тестирования'},
#  {'text': 'Так, например, здесь вы можете просмотреть эти тесты, а затем посмотреть, какие результаты были получены в результате теста'},
#  {'text': 'И это то, что вы сейчас увидите. Давайте рассмотрим другой пример. Это немного сложнее'},
#  {'text': 'Итак, в папке с исходным кодом у меня также есть папка с переводом'},
#  {'text': 'и есть файл API перевода, и я'},
#  {'text': 'Позвольте мне просто покончить с этим.'},
#  {'text': 'Если вы прокрутите страницу вниз, то увидите, что здесь у нас есть множество функций,'},
#  {'text': 'например, разделение по точке останова,'},
#  {'text': 'переведите его, вызвав OpenAI translator,'},
#  {'text': 'асинхронная версия этого, а также пара других вещей.'},
#  {'text': 'Теперь, если вы хотите добавить тест для этого конкретного файла,'}]

# %%
# Extend the translations list to match the length of the DataFrame
extended_translations = [t['text'] for t in translations] + [None] * (len(df) - len(translations))

# Add the extended translations as a new column
df['Yandex'] = extended_translations
df
# Out:
#        Start Time      End Time  \
# 0    00:00:00.000  00:00:06.380
# 1    00:00:07.200  00:00:09.800
# 2    00:00:09.800  00:00:15.640
# 3    00:00:16.000  00:00:20.480
# 4    00:00:20.480  00:00:25.959
# ..            ...           ...
# 231  00:15:47.219  00:15:49.138
# 232  00:15:49.138  00:15:52.378
# 233  00:15:52.378  00:15:55.459
# 234  00:15:55.459  00:15:58.698
# 235  00:15:58.698  00:16:01.098
#
#                                                   Text  \
# 0    Today I'm going to walk you through how to set...
# 1             I'll start with code that has zero tests
# 2    I'll add PyTest, show you step-by-step how to ...
# 3    Including one feature almost no one knows abou...
# 4    I'll share some practical tips to make your te...
# ..                                                 ...
# 231      If you want to learn more about what to test,
# 232        how to set up a complete set of unit tests,
# 233  check out this video where I do a refactoring ...
# 234         and use unit tests to create a safety net.
# 235        Thanks for watching, and see you next time.
#
#                                                 Yandex
# 0    Сегодня я расскажу вам о том, как настроить Py...
# 1                 Я начну с кода, в котором нет тестов
# 2    Я добавлю PyTest, покажу вам шаг за шагом, как...
# 3    Включая одну функцию, о которой почти никто не...
# 4    Я поделюсь несколькими практическими советами,...
# ..                                                 ...
# 231                                               None
# 232                                               None
# 233                                               None
# 234                                               None
# 235                                               None
#
# [236 rows x 4 columns]

# %%
out_tsv = sub_tsv.replace('.en.tsv', '.en-ru.tsv')
out_tsv
# Out:
# '..\\files\\arjan\\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.en-ru.tsv'

# %%
df.to_csv(out_tsv, sep='\t', index=False)

# %% [markdown]
# ## Converting human-processed translation into .vtt

# %%
translated_tsv = r'..\files\arjan\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.en_pruned_mm.tsv.txt'
translated_tsv
# Out:
# '..\\files\\arjan\\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.en_pruned_mm.tsv.txt'

# %%
out_df = pd.read_csv(translated_tsv, sep='\t')
out_df
# Out:
#        Start Time      End Time  \
# 0    00:00:00.000  00:00:06.380
# 1    00:00:07.200  00:00:09.800
# 2    00:00:09.800  00:00:15.640
# 3    00:00:16.000  00:00:20.480
# 4    00:00:20.480  00:00:25.959
# ..            ...           ...
# 231  00:15:47.219  00:15:49.138
# 232  00:15:49.138  00:15:52.378
# 233  00:15:52.378  00:15:55.459
# 234  00:15:55.459  00:15:58.698
# 235  00:15:58.698  00:16:01.098
#
#                                                   Text  \
# 0    Today I'm going to walk you through how to set...
# 1             I'll start with code that has zero tests
# 2    I'll add PyTest, show you step-by-step how to ...
# 3    Including one feature almost no one knows abou...
# 4    I'll share some practical tips to make your te...
# ..                                                 ...
# 231      If you want to learn more about what to test,
# 232        how to set up a complete set of unit tests,
# 233  check out this video where I do a refactoring ...
# 234         and use unit tests to create a safety net.
# 235        Thanks for watching, and see you next time.
#
#                                                     MM
# 0    Сегодня я продемонстрирую, как настроить PyTes...
# 1                      Начав с кода вообще без тестов,
# 2    я установлю PyTest, а затем в пошаговом режиме...
# 3    включая одну реально крутую фишку, о которой п...
# 4    и дам несколько полезных подсказок, как сделат...
# ..                                                 ...
# 231  При желании узнать больше о том, что именно тр...
# 232  и как сформировать исчерпывающий набор модульн...
# 233  посмотрите вот это видео. В нем я выполняю зад...
# 234      и использую модульные тесты для подстраховки.
# 235             Спасибо за просмотр и до новых встреч!
#
# [236 rows x 4 columns]

# %%
def save_to_vtt(df, output_file="output.vtt"):
    """Save a Pandas DataFrame back to a .vtt subtitle file. (suggested by ChatGPT)"""
    with open(output_file, "w", encoding="utf-8") as f:
        f.write("WEBVTT\n\n")  # VTT header
        
        for _, row in df.iterrows():
            f.write(f"{row['Start Time']} --> {row['End Time']}\n")
            f.write(f"{row['Text']}\n\n")  # Double new line between captions

# %%
out_df.drop(columns=['Text'], inplace=True)
out_df.rename(columns={'MM': 'Text'}, inplace=True)
out_df
# Out:
#        Start Time      End Time  \
# 0    00:00:00.000  00:00:06.380
# 1    00:00:07.200  00:00:09.800
# 2    00:00:09.800  00:00:15.640
# 3    00:00:16.000  00:00:20.480
# 4    00:00:20.480  00:00:25.959
# ..            ...           ...
# 231  00:15:47.219  00:15:49.138
# 232  00:15:49.138  00:15:52.378
# 233  00:15:52.378  00:15:55.459
# 234  00:15:55.459  00:15:58.698
# 235  00:15:58.698  00:16:01.098
#
#                                                   Text
# 0    Сегодня я продемонстрирую, как настроить PyTes...
# 1                      Начав с кода вообще без тестов,
# 2    я установлю PyTest, а затем в пошаговом режиме...
# 3    включая одну реально крутую фишку, о которой п...
# 4    и дам несколько полезных подсказок, как сделат...
# ..                                                 ...
# 231  При желании узнать больше о том, что именно тр...
# 232  и как сформировать исчерпывающий набор модульн...
# 233  посмотрите вот это видео. В нем я выполняю зад...
# 234      и использую модульные тесты для подстраховки.
# 235             Спасибо за просмотр и до новых встреч!
#
# [236 rows x 3 columns]

# %%
out_vtt = translated_tsv.replace('.en_pruned_mm.tsv.txt', '.mm.ru.vtt')
out_vtt
# Out:
# '..\\files\\arjan\\This Is How Marie Kondo Sets up Her Pytest_jxqGsJEhiAg.mm.ru.vtt'

# %%
save_to_vtt(out_df, out_vtt)

# %%
response.text
# Out:
# '{\n "code": 3,\n "message": "total texts length must be not greater than 10000",\n "details": [\n  {\n   "@type": "type.googleapis.com/google.rpc.RequestInfo",\n   "requestId": "d75c2d53-9585-4e38-8181-e12e4d7ac638"\n  }\n ]\n}\n'

# %%
sum([len(text) for text in texts])
# Out:
# 16026
